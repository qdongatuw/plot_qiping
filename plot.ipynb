# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
file = r"summary_0614_2.xlsx"

# %%
df = pd.read_excel(file)

# %%
df
# Out:
#    Unnamed: 0 genotype  Rin_vclamp (MOhms)  Access resistance (MOhms)  \
# 0         Q56       KO          190.561822                  17.898555
# 1         Q57       KO          708.826905                  18.280366
# 2         Q58       KO          311.509347                   7.274540
# 3         Q59       KO          250.287725                   7.423671
# 4         Q61       KO          424.758339                  15.188919
# ..        ...      ...                 ...                        ...
# 75         U9       WT          166.586924                  17.198368
# 76        U10       WT           96.632451                  15.844427
# 77        U11       WT          204.338070                  17.189201
# 78        U12       WT          253.412357                  15.549794
# 79        U13       WT          264.143647                  15.259724
#
#     Tau_vclamp (ms)  Cm_vclamp (pF)  Inward current peak - -70.0 mV (pA)  \
# ...

# %%
df_wt = df[df['genotype'] == 'WT']
df_ko = df[df['genotype'] == 'KO']

# %%
writer = pd.ExcelWriter('mbd1_2.xlsx', engine='openpyxl')

for column in df.iloc[:, 2:]:
    groups = dict()
    groups['WT'] = df_wt[column]
    groups['KO'] = df_ko[column]

    pd.DataFrame(groups).to_excel(writer, sheet_name=column, index=False)
writer.save()
# Out:
# C:\Users\dongq\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
# C:\Users\dongq\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
# ...

# %%
import openpyxl
from openpyxl.utils import get_column_letter

# Load the Excel file
workbook = openpyxl.load_workbook('mbd1_2.xlsx')


worksheets = workbook.sheetnames

for i in worksheets:
    worksheet = workbook[i]
    # Loop through each row and column
    max_row = worksheet.max_row
    max_column = worksheet.max_column
    for column in range(1, worksheet.max_column + 1):

        for row in reversed(list(range(1, worksheet.max_row + 1))):
                    # Check if cell is empty
            if not worksheet.cell(row=row, column=column).value:
                # Delete the cell
                # worksheet.delete_rows(row, amount=1)
                # Shift cells up
                print(f'{get_column_letter(column)}{row+1}:{get_column_letter(column)}{max_row}')
                worksheet.move_range(f'{get_column_letter(column)}{row+1}:{get_column_letter(column)}{max_row+1}', rows=-1)
                

# Save the changes
workbook.save('modified_0614_2.xlsx')
# Out:
# C:\Users\dongq\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
# A64:A81
# A47:A81
# A46:A81
# A45:A81
# A44:A81
# A43:A81
# A42:A81
# A41:A81
# A40:A81
# A39:A81
# A38:A81
# A37:A81
# A36:A81
# A35:A81
# A24:A81
# A23:A81
# A22:A81
# A21:A81
# A20:A81
# A19:A81
# A18:A81
# A17:A81
# A16:A81
# A15:A81
# A14:A81
# A13:A81
# A12:A81
# A11:A81
# A10:A81
# A9:A81
# A8:A81
# A7:A81
# A6:A81
# A5:A81
# A4:A81
# A3:A81
# B82:B81
# B81:B81
# B80:B81
# B79:B81
# B78:B81
# B77:B81
# B76:B81
# B75:B81
# B74:B81
# B73:B81
# B72:B81
# B71:B81
# B70:B81
# B69:B81
# B68:B81
# B67:B81
# B66:B81
# B65:B81
# B64:B81
# B63:B81
# B62:B81
# B61:B81
# B60:B81
# B59:B81
# B58:B81
# B57:B81
# B56:B81
# ...
