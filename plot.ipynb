# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
file = r"summary_0614.xlsx"

# %%
df = pd.read_excel(file)

# %%
df
# Out:
#    Unnamed: 0 genotype  Rin_vclamp (MOhms)  Access resistance (MOhms)  \
# 0         Q56       KO          190.561822                  17.898555
# 1         Q57       KO          708.826905                  18.280366
# 2         Q58       KO          311.509347                   7.274540
# 3         Q59       KO          250.287725                   7.423671
# 4         Q61       KO          424.758339                  15.188919
# ..        ...      ...                 ...                        ...
# 75         U9       WT          166.586924                  17.198368
# 76        U10       WT           96.632451                  15.844427
# 77        U11       WT          204.338070                  17.189201
# 78        U12       WT          253.412357                  15.549794
# 79        U13       WT          264.143647                  15.259724
#
#     Tau_vclamp (ms)  Cm_vclamp (pF)  Inward current peak - -70.0 mV (pA)  \
# ...

# %%
df_wt = df[df['genotype'] == 'WT']
df_ko = df[df['genotype'] == 'KO']

# %%
writer = pd.ExcelWriter('mbd1.xlsx', engine='openpyxl')

for column in df.iloc[:, 2:]:
    groups = dict()
    groups['WT'] = df_wt[column]
    groups['KO'] = df_ko[column]

    pd.DataFrame(groups).to_excel(writer, sheet_name=column, index=False)
writer.save()
# Out:
# C:\Users\dongq\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
# C:\Users\dongq\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
# ...

# %%
import openpyxl
from openpyxl.utils import get_column_letter

# Load the Excel file
workbook = openpyxl.load_workbook('mbd1.xlsx')


# Select worksheet
worksheet = workbook.active

# Loop through each row and column
for row in range(1, worksheet.max_row + 1):
    for column in range(1, worksheet.max_column + 1):
        print(row, column)
        # Check if cell is empty
        if not worksheet.cell(row=row, column=column).value:
            # Delete the cell
            worksheet.delete_rows(row, amount=1)
            # Shift cells up
            worksheet.move_range(f'{get_column_letter(column)}{row+1}:{get_column_letter(worksheet.max_column)}{worksheet.max_row}', rows=-1)

# Save the changes
workbook.save('mbd10614.xlsx')
# Out:
# C:\Users\dongq\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
# 1 1
# 1 2
# 2 1
# 2 2
# 3 1
# 3 2
# 4 1
# 4 2
# 5 1
# 5 2
# 6 1
# 6 2
# 7 1
# 7 2
# 8 1
# 8 2
# 9 1
# 9 2
# 10 1
# 10 2
# 11 1
# 11 2
# 12 1
# 12 2
# 13 1
# 13 2
# 14 1
# 14 2
# 15 1
# 15 2
# 16 1
# 16 2
# 17 1
# 17 2
# 18 1
# 18 2
# 19 1
# 19 2
# 20 1
# 20 2
# 21 1
# 21 2
# 22 1
# 22 2
# 23 1
# 23 2
# 24 1
# 24 2
# 25 1
# 25 2
# 26 1
# 26 2
# 27 1
# 27 2
# 28 1
# 28 2
# 29 1
# 29 2
# 30 1
# 30 2
# 31 1
# 31 2
# 32 1
# 32 2
# 33 1
# 33 2
# 34 1
# 34 2
# 35 1
# 35 2
# ---------------------------------------------------------------------------
# ...
